# %% [markdown]
# Create Time: 2025-06-23 18:50
# Creator: Qingyuan Hu
# Python Version: 3.11.5
# Description: This file is used to do some data cleaing and preprocessing.

# %%
# %pip install pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_timestamp

# Start Spark
spark = SparkSession.builder.appName("Smart_Grid").getOrCreate()
# Out:
# Requirement already satisfied: pyspark in /opt/homebrew/anaconda3/lib/python3.11/site-packages (4.0.0)
# Requirement already satisfied: py4j==0.10.9.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/06/23 19:02:09 WARN Utils: Your hostname, MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 10.110.234.6 instead (on interface en0)
# 25/06/23 19:02:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/23 19:02:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Download dataset
import requests
path = "https://raw.githubusercontent.com/huqingyuan314/DS5110-25Summer-Project/refs/heads/main/datasets/Smart%20Grid%20Real-Time%20Load%20Monitoring%20Dataset/smart_grid_dataset.csv"
req = requests.get(path)
url_content = req.content

csv_file_name = 'smart_grid_data.csv'
with open(csv_file_name, 'wb') as csv_file:
    csv_file.write(url_content)

# Read into PySpark DataFrame
df = spark.read.csv(csv_file_name, header=True, inferSchema=True)
df.printSchema()
df.show(5)
# Out:
# root
#  |-- Timestamp: timestamp (nullable = true)
#  |-- Voltage (V): double (nullable = true)
#  |-- Current (A): double (nullable = true)
#  |-- Power Consumption (kW): double (nullable = true)
#  |-- Reactive Power (kVAR): double (nullable = true)
#  |-- Power Factor: double (nullable = true)
#  |-- Solar Power (kW): double (nullable = true)
#  |-- Wind Power (kW): double (nullable = true)
#  |-- Grid Supply (kW): double (nullable = true)
#  |-- Voltage Fluctuation (%): double (nullable = true)
#  |-- Overload Condition: integer (nullable = true)
#  |-- Transformer Fault: integer (nullable = true)
#  |-- Temperature (°C): double (nullable = true)
#  |-- Humidity (%): double (nullable = true)
#  |-- Electricity Price (USD/kWh): double (nullable = true)
#  |-- Predicted Load (kW): double (nullable = true)
#
# +-------------------+------------------+-----------------+----------------------+---------------------+------------------+------------------+------------------+----------------+-----------------------+------------------+-----------------+------------------+-----------------+---------------------------+-------------------+
# |          Timestamp|       Voltage (V)|      Current (A)|Power Consumption (kW)|Reactive Power (kVAR)|      Power Factor|  Solar Power (kW)|   Wind Power (kW)|Grid Supply (kW)|Voltage Fluctuation (%)|Overload Condition|Transformer Fault|  Temperature (°C)|     Humidity (%)|Electricity Price (USD/kWh)|Predicted Load (kW)|
# +-------------------+------------------+-----------------+----------------------+---------------------+------------------+------------------+------------------+----------------+-----------------------+------------------+-----------------+------------------+-----------------+---------------------------+-------------------+
# |2024-01-01 00:00:00|232.48357076505616|5.124672741462765|    1.1914022179376131|   0.3990291541911931|0.9077655280980953| 46.61484530540027| 26.39956604563302|             0.0|     1.0559370521676525|                 0|                0|17.842767064400007|64.52335267421111|         0.4161564107971101| 1.2331584224739387|
# |2024-01-01 00:15:00| 229.3086784941441|22.21351868141248|     5.093752613539678|   1.2480300128782689|0.8318133316322733| 6.907169503249216|18.555011274572458|             0.0|    -3.9109018341584445|                 1|                0| 18.75369822819185|49.67193960492017|        0.49233436510627315|  5.247824239531332|
# |2024-01-01 00:30:00|233.23844269050346|46.13221715719354|    10.759806487603946|   2.7904635769346258| 0.999005396391214| 15.47763994196853|12.905025033981705|             0.0|   -0.19755050769516114|                 0|                0| 16.71932518134446|48.47276856045443|        0.42778499476993215| 10.580278295882652|
